# %% [markdown]
# <a href="https://colab.research.google.com/github/vandien201462C/projectcuoiky/blob/main/Fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fashion
# Phạm Văn Diên - 20146485

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/Data_fashion/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('bag'):
    output = 1.0
  if file.startswith('dress'):
    output = 2.0
  if file.startswith('glasses'):
    output = 3.0
  if file.startswith('hat'):
    output = 4.0
  if file.startswith('pants'):
    output = 5.0
  if file.startswith('shirt'):
    output = 6.0
  if file.startswith('shoes'):
    output = 7.0
  if file.startswith('short'):
    output = 8.0
  if file.startswith('watch'):
    output = 9.0

  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
  
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (3592, 100, 100, 3) (3592,)

# %%
photos = photos.astype('float32')/255.0
print(photos.shape)
# Out:
# (3592, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (2154, 100, 100, 3)
# (2154,)
# (719, 100, 100, 3)
# (719,)
# (719, 100, 100, 3)
# (719,)

# %%
image_test = 20
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('item: ', trainY[image_test])
# Out:
# item:  7.0

# %%
for i in range(25):  # 25 hình ảnh
  plt.subplot(5,5,i+1) # 5 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
 #one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (2154, 10)
# (719, 10)
# (719, 10)

# %%
batch_size=32
epochs = 50
classes = 10

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'tanh', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))




# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'tanh'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 100, 32)      896
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 100, 100, 32)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 21632)             0
#
#  dense_2 (Dense)             (None, 128)               2769024
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 2,863,562
# Trainable params: 2,863,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 68/68 [==============================] - 68s 1s/step - loss: 1.2262 - accuracy: 0.5859 - val_loss: 0.9633 - val_accuracy: 0.6509
# Epoch 2/50
# 68/68 [==============================] - 71s 1s/step - loss: 0.7945 - accuracy: 0.7205 - val_loss: 0.7327 - val_accuracy: 0.7455
# Epoch 3/50
# 68/68 [==============================] - 63s 933ms/step - loss: 0.5563 - accuracy: 0.8166 - val_loss: 0.5565 - val_accuracy: 0.8108
# Epoch 4/50
# 68/68 [==============================] - 59s 875ms/step - loss: 0.3901 - accuracy: 0.8742 - val_loss: 0.4703 - val_accuracy: 0.8317
# Epoch 5/50
# 68/68 [==============================] - 64s 950ms/step - loss: 0.2651 - accuracy: 0.9257 - val_loss: 0.4139 - val_accuracy: 0.8651
# Epoch 6/50
# 68/68 [==============================] - 59s 877ms/step - loss: 0.1673 - accuracy: 0.9568 - val_loss: 0.3869 - val_accuracy: 0.8637
# Epoch 7/50
# 68/68 [==============================] - 67s 987ms/step - loss: 0.0922 - accuracy: 0.9856 - val_loss: 0.3920 - val_accuracy: 0.8804
# Epoch 8/50
# 68/68 [==============================] - 64s 951ms/step - loss: 0.0497 - accuracy: 0.9977 - val_loss: 0.3539 - val_accuracy: 0.8762
# Epoch 9/50
# 68/68 [==============================] - 59s 872ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.3605 - val_accuracy: 0.8818
# Epoch 10/50
# 68/68 [==============================] - 64s 942ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.8818
# Epoch 11/50
# 68/68 [==============================] - 67s 984ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.3726 - val_accuracy: 0.8776
# Epoch 12/50
# 68/68 [==============================] - 69s 1s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.8762
# Epoch 13/50
# 68/68 [==============================] - 65s 957ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.3790 - val_accuracy: 0.8846
# Epoch 14/50
# 68/68 [==============================] - 60s 883ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3791 - val_accuracy: 0.8860
# Epoch 15/50
# 68/68 [==============================] - 62s 921ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.8790
# Epoch 16/50
# 68/68 [==============================] - 60s 883ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.8818
# Epoch 17/50
# 68/68 [==============================] - 65s 958ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.3924 - val_accuracy: 0.8846
# Epoch 18/50
# 68/68 [==============================] - 65s 960ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.8832
# Epoch 19/50
# 68/68 [==============================] - 60s 883ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4017 - val_accuracy: 0.8846
# Epoch 20/50
# 68/68 [==============================] - 67s 982ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3999 - val_accuracy: 0.8832
# Epoch 21/50
# 68/68 [==============================] - 61s 902ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.8860
# Epoch 22/50
# 68/68 [==============================] - 59s 876ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.8832
# Epoch 23/50
# 68/68 [==============================] - 60s 882ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4042 - val_accuracy: 0.8846
# Epoch 24/50
# 68/68 [==============================] - 67s 980ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4045 - val_accuracy: 0.8846
# Epoch 25/50
# 68/68 [==============================] - 65s 955ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4091 - val_accuracy: 0.8846
# Epoch 26/50
# 68/68 [==============================] - 65s 960ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4141 - val_accuracy: 0.8832
# Epoch 27/50
# 68/68 [==============================] - 60s 879ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.8860
# Epoch 28/50
# 68/68 [==============================] - 66s 981ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4175 - val_accuracy: 0.8860
# Epoch 29/50
# 68/68 [==============================] - 59s 877ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.8832
# Epoch 30/50
# 68/68 [==============================] - 64s 940ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4163 - val_accuracy: 0.8846
# Epoch 31/50
# 68/68 [==============================] - 65s 955ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.8846
# Epoch 32/50
# 68/68 [==============================] - 61s 899ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8860
# Epoch 33/50
# 68/68 [==============================] - 65s 947ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.8846
# Epoch 34/50
# 68/68 [==============================] - 61s 897ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4243 - val_accuracy: 0.8846
# Epoch 35/50
# 68/68 [==============================] - 60s 878ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4275 - val_accuracy: 0.8790
# Epoch 36/50
# 68/68 [==============================] - 65s 960ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.8846
# Epoch 37/50
# 68/68 [==============================] - 62s 907ms/step - loss: 9.6308e-04 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.8860
# Epoch 38/50
# 68/68 [==============================] - 61s 898ms/step - loss: 9.0891e-04 - accuracy: 1.0000 - val_loss: 0.4312 - val_accuracy: 0.8832
# Epoch 39/50
# 68/68 [==============================] - 60s 881ms/step - loss: 8.5920e-04 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8818
# Epoch 40/50
# 68/68 [==============================] - 65s 961ms/step - loss: 8.1536e-04 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8846
# Epoch 41/50
# 68/68 [==============================] - 60s 879ms/step - loss: 7.7356e-04 - accuracy: 1.0000 - val_loss: 0.4390 - val_accuracy: 0.8818
# Epoch 42/50
# 68/68 [==============================] - 66s 968ms/step - loss: 7.3540e-04 - accuracy: 1.0000 - val_loss: 0.4338 - val_accuracy: 0.8832
# Epoch 43/50
# 68/68 [==============================] - 59s 876ms/step - loss: 6.9680e-04 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.8846
# Epoch 44/50
# 68/68 [==============================] - 64s 942ms/step - loss: 6.6031e-04 - accuracy: 1.0000 - val_loss: 0.4423 - val_accuracy: 0.8818
# Epoch 45/50
# 68/68 [==============================] - 64s 952ms/step - loss: 6.2816e-04 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.8860
# Epoch 46/50
# 68/68 [==============================] - 62s 908ms/step - loss: 6.0189e-04 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8818
# Epoch 47/50
# 68/68 [==============================] - 65s 955ms/step - loss: 5.6791e-04 - accuracy: 1.0000 - val_loss: 0.4450 - val_accuracy: 0.8860
# Epoch 48/50
# 68/68 [==============================] - 59s 875ms/step - loss: 5.3890e-04 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8818
# Epoch 49/50
# 68/68 [==============================] - 61s 886ms/step - loss: 5.1389e-04 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.8776
# Epoch 50/50
# 68/68 [==============================] - 61s 895ms/step - loss: 4.9005e-04 - accuracy: 1.0000 - val_loss: 0.4521 - val_accuracy: 0.8832
# 3202.335951089859

# %%
model.save('/content/drive/MyDrive/Model_Fashion.h5')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'bag', 2:'dress',3:'glasses',
       4:'hat',5:'pants',6:'shirt',
       7:'shoes',8:'short',9:'watch'}  
#test
filePath = '/content/drive/MyDrive/Data_fashion/bag (108).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 158ms/step
# Predicted:  bag

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=100, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 4/4 [==============================] - 1s 147ms/step
# Accuracy: 90.0 %

# %%
name= {1:'bag', 2:'dress',3:'glasses',
       4:'hat',5:'pants',6:'shirt',
       7:'shoes',8:'short',9:'watch'}  
#test
filePath = '/content/drive/MyDrive/Data_fashion/hat (108).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Predicted:  hat
